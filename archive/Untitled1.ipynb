# %%
/*
Theme Name: GeneratePress Child
Description: GeneratePress 테마의 차일드 테마입니다
Author: 내 이름
Template: generatepress
Version: 1.0.0
*/

/* 여기에 CSS 코드를 추가하세요 */
/* 카테고리 페이지에만 적용 */
.category .content-area {
    max-width: 100%;
    padding-left: 20px !important;  /* 데스크탑용 좌우 패딩 추가 */
    padding-right: 20px !important; /* 데스크위탑용 좌우 패딩 추가 */
}

/* 열을 1개로 변경 (그리드 제거) */
.category .content-area .site-main {
    display: block;
}

/* 각 포스트 아이템 스타일링 */
.category .content-area .site-main article {
    border: 1px solid #eee;
    border-radius: 5px;
    overflow: hidden;
    box-shadow: 0 2px 5px rgba(0,0,0,0.1);
    padding: 20px;
    background: white;
    margin-bottom: 20px; /* 포스트 간격 줄임 - 원래 30px */
    position: relative;
    transition: transform 0.3s ease, box-shadow 0.3s ease; /* 호버 효과를 위한 전환 추가 */
}

/* 아티클 호버 효과 - 포스트 전체에 적용 */
.category .content-area .site-main article:hover {
    border-color: #ccc !important;
    box-shadow: 0 5px 15px rgba(0,0,0,0.1) !important;
}

/* 타이틀 스타일 - 타이틀 상단 간격 줄임 */
.category .content-area .site-main article .entry-title,
.category .content-area .site-main article h2.entry-title {
    display: block !important;
    visibility: visible !important;
    margin: 0 0 5px 0 !important; /* 하단 마진 유지 */
    padding-top: 0 !important; /* 상단 패딩 제거 */
    font-size: 30px !important;
    font-weight: 900 !important;
}

.category .content-area .site-main article .entry-title a,
.category .content-area .site-main article h2.entry-title a {
    color: #B00808 !important;
    text-decoration: none !important;
    display: block !important;
    visibility: visible !important;
    transition: color 0.3s ease; /* 호버 효과를 위한 전환 - 크기 변경 제거하고 색상 전환만 */
}

/* 타이틀 호버 효과 - 색상만 어둡게 변경 */
.category .content-area .site-main article .entry-title a:hover,
.category .content-area .site-main article h2.entry-title a:hover {
    color: #800404 !important; /* 더 어두운 빨간색 */
}

/* 날짜 형식 스타일 - 완전히 숨기기 */
.category .content-area .site-main article .entry-meta {
    display: none !important;
    visibility: hidden !important;
    height: 0 !important;
    margin: 0 !important;
    padding: 0 !important;
}

/* 작성자 정보 숨기기 */
.category .content-area .site-main article .byline {
    display: none !important;
}

/* 요약 스타일 - 제목과 간격 줄임 */
.category .content-area .site-main article .entry-summary {
    display: block !important;
    margin-top: 20px !important; /* 상단 간격 제거 */
    margin-bottom: 30px !important; /* 버튼과의 간격은 유지 */
    overflow: hidden !important;
    max-height: 3em !important;
    line-height: 1.5 !important;
    transition: color 0.3s ease !important;
}

/* 발췌문 호버 효과 - 배경색 변경 제거 */
.category .content-area .site-main article .entry-summary:hover {
    /* 배경색 변경 제거 */
}

.category .content-area .site-main article .entry-summary p {
    display: -webkit-box !important;
    -webkit-line-clamp: 2 !important;
    -webkit-box-orient: vertical !important;
    overflow: hidden !important;
    text-overflow: ellipsis !important;
    margin: 0 !important;
    color: #777 !important; /* 기본 색상 지정 */
    transition: color 0.3s ease !important;
}

.category .content-area .site-main article .entry-summary p:hover {
    color: #333 !important; /* 호버 시 더 어두운 색상으로 변경 */
}

/* 더 읽기 버튼 스타일 수정 (기존 버튼 수정) */
.category .content-area .site-main article .read-more,
.category .content-area .site-main article a.read-more,
.category .content-area .site-main article .more-link,
.category .content-area .site-main article a.more-link,
.category .content-area .site-main article a.more-tag,
.category article a.more-link,
.category article a.read-more,
.category article a[class*="more"],
.category .read-more-button,
.category .more-button,
.category .more-tag,
.category article .more-link,
.category .content-area article .more-link,
.category article .continue-reading,
.category .continue-reading,
.category .read-more-link,
.category article .read-more-link {
    display: inline-block !important;
    visibility: visible !important;
    opacity: 1 !important;
    height: auto !important;
    width: auto !important;
    background-color: #B00808 !important;
    color: white !important;
    font-size: 21px !important;
    font-weight: 1000 !important;
    padding: 10px 25px !important;
    border-radius: 15px !important;
    text-decoration: none !important;
    cursor: pointer !important;
    transition: all 0.3s ease !important;
    position: absolute !important;
    bottom: 20px !important;
    left: 20px !important;
    margin: 0 !important;
    z-index: 1000 !important;
    box-sizing: border-box !important;
    text-align: center !important;
}

/* 더 읽기 버튼 텍스트 변경 */
.category .content-area .site-main article .read-more,
.category .content-area .site-main article a.read-more,
.category .content-area .site-main article .more-link,
.category .content-area .site-main article a.more-link,
.category .content-area .site-main article a.more-tag,
.category article a.more-link,
.category article a.read-more,
.category article a[class*="more"],
.category .read-more-button,
.category .more-button,
.category .more-tag,
.category article .more-link,
.category .content-area article .more-link,
.category article .continue-reading,
.category .continue-reading,
.category .read-more-link,
.category article .read-more-link {
    font-size: 0 !important; /* 기존 텍스트 숨기기 */
}

.category .content-area .site-main article .read-more::after,
.category .content-area .site-main article a.read-more::after,
.category .content-area .site-main article .more-link::after,
.category .content-area .site-main article a.more-link::after,
.category .content-area .site-main article a.more-tag::after,
.category article a.more-link::after,
.category article a.read-more::after,
.category article a[class*="more"]::after,
.category .read-more-button::after,
.category .more-button::after,
.category .more-tag::after,
.category article .more-link::after,
.category .content-area article .more-link::after,
.category article .continue-reading::after,
.category .continue-reading::after,
.category .read-more-link::after,
.category article .read-more-link::after {
    content: "더 읽기" !important;
    font-size: 21px !important;
    font-weight: 1000 !important;
}

/* 버튼 호버 효과 */
.category .content-area .site-main article .read-more:hover,
.category .content-area .site-main article a.read-more:hover,
.category .content-area .site-main article .more-link:hover,
.category .content-area .site-main article a.more-link:hover,
.category .content-area .site-main article a.more-tag:hover,
.category article a.more-link:hover,
.category article a.read-more:hover,
.category article a[class*="more"]:hover,
.category .read-more-button:hover,
.category .more-button:hover,
.category .more-tag:hover,
.category article .more-link:hover,
.category .content-area article .more-link:hover,
.category article .continue-reading:hover,
.category .continue-reading:hover,
.category .read-more-link:hover,
.category article .read-more-link:hover {
    background-color: #900606 !important;
    transform: scale(1.05) !important;
    box-shadow: 0 2px 5px rgba(0,0,0,0.2) !important;
}

/* 버튼 영역 확보 */
.category .content-area .site-main article {
    padding-bottom: 85px !important;
}

/* 기존 ::after 스타일 제거 (새 버튼을 생성하는 대신 기존 버튼을 스타일링하므로) */
.category .content-area .site-main article::after {
    content: none !important;
    display: none !important;
}

/* 카테고리와 댓글 정보 숨기기 */
.category .content-area .site-main article .cat-links,
.category .content-area .site-main article .comments-link,
.category .content-area .site-main article footer.entry-meta {
    display: none !important;
}

/* 페이지네이션 스타일 */
.category .content-area .navigation {
    text-align: center;
    margin-top: 30px;
    margin-bottom: 50px;
}

.category .content-area .navigation .page-numbers {
    padding: 8px 15px;
    margin: 0 5px;
    border: 1px solid #ddd;
    border-radius: 4px;
    display: inline-block;
    transition: background-color 0.3s, color 0.3s, border-color 0.3s; /* 호버 효과 추가 */
}

/* 페이지네이션 호버 효과 */
.category .content-area .navigation .page-numbers:hover {
    background: #f0f0f0;
    border-color: #bbb;
}

.category .content-area .navigation .page-numbers.current {
    background: #B00808;
    color: white;
    border-color: #B00808;
}

/* 모든 내부 요소에 패딩 제거 */
.category .content-area .site-main article > * {
    padding-left: 0 !important;
    margin-left: 0 !important;
}

/* 아티클 패딩 조정 - 상단 패딩 축소 */
.category .content-area .site-main article {
    padding: 10px 20px 20px 20px !important; /* 상단 패딩 줄임 (10px) */
    box-sizing: border-box !important;
}

/* 모바일 버전에서 좌우 패딩 추가 */
@media (max-width: 768px) {
    .category .content-area .site-main article {
        padding-left: 15px !important;
        padding-right: 15px !important;
    }
    
    /* 컨테이너에도 좌우 패딩 추가 */
    .category .content-area {
        padding-left: 15px !important;
        padding-right: 15px !important;
    }
}

/* 이미지 섬네일 완전히 숨기기 */
.category .content-area .site-main article .post-thumbnail,
.category .content-area .site-main article .entry-thumbnail,
.category .content-area .site-main article .thumbnail,
.category .content-area .site-main article figure,
.category .content-area .site-main article img.attachment-post-thumbnail,
.category .content-area .site-main article img.wp-post-image,
.category .content-area .site-main article .featured-image,
.category .content-area .site-main article div[class*="thumbnail"],
.category .content-area .site-main article a[class*="thumbnail"],
.category article .wp-post-image,
.category article img.featured {
    display: none !important;
    visibility: hidden !important;
    opacity: 0 !important;
    width: 0 !important;
    height: 0 !important;
    position: absolute !important;
    left: -9999px !important;
    top: -9999px !important;
    margin: 0 !important;
    padding: 0 !important;
    border: none !important;
    overflow: hidden !important;
}

/* 이미지 컨테이너 공간도 제거 */
.category .content-area .site-main article .entry-content > div:empty,
.category .content-area .site-main article .entry-content > p:empty,
.category .content-area .site-main article div:has(> img.wp-post-image),
.category .content-area .site-main article a:has(> img.wp-post-image) {
    display: none !important;
    margin: 0 !important;
    padding: 0 !important;
    height: 0 !important;
}

/* 이미지가 제거된 후 컨텐츠 간격 조정 */
.category .content-area .site-main article .entry-content,
.category .content-area .site-main article .entry-summary {
    margin-top: 10px !important;
}
/* css 속성 수정
.site.grid-container {
  height: 100% !important;
  min-height: 100vh;
}
img {
  height: auto;
  max-width: 100%;
  display: block;
}

/* Lazy-load 이미지의 자리 확보 */
img[loading="lazy"] {
  min-height: 200px;
  background-color: #f4f4f4;
}


/* 전체 레이아웃이 밀리는 것 방지 */
#page {
  min-height: 100vh; /* 최소한 뷰포트 높이만큼은 확보 */
}
